# %% [markdown]
# ## The Project: AI Agents for Diverse Movie Recommendations using LangGraph
#
# This project builds an AI agent system using the **LangGraph** framework to provide personalized movie recommendations based on the **MovieLens 100K** dataset. The system uses a pre-trained **NeuMF** model ([He et al., 2017](https://dl.acm.org/doi/10.1145/3038912.3052569)) for collaborative filtering and is enhanced with multiple agents:
#
# 1. **RecommenderAgent**: Predicts top-20 movies for each user based on the trained NeuMF model.
# 2. **DiversityRerankerAgent**: Selects the most diverse top-5 subset from the recommendations by balancing rating quality and genre variety.
# 3. **CritiqueAgent**: Uses a language model (e.g., Granite) to evaluate the recommendation list and provide critique about thematic richness, emotional depth, and genre coverage.
#
# Each agent operates within a **LangGraph pipeline**, enabling structured reasoning and modular evaluation. The full system prints user history, generates diverse recommendations, and explains potential weaknesses in the results.

# %% [markdown]
# `Graph:
#   A[RecommenderAgent] --> B[DiversityRerankerAgent]
#   B --> C[CritiqueAgent]
#   C --> D[END]
# `

# %% [markdown]
# # The Dataset: MovieLens 100K
#
# The experiments are based on the **MovieLens 100K dataset**, a widely used benchmark in recommender systems research.
#
# - **Size:** 100,000 ratings
# - **Users:** 943
# - **Movies:** 1,682
# - **Format:** tab-delimited files (CSV-like)
#
# ## Main Columns
# - **userId** – unique identifier of each user (anonymized, 1–943).
# - **movieId** – unique identifier of each movie (1–1682).
# - **rating** – explicit rating from 1 to 5, where higher values indicate stronger preference.
# - **timestamp** – UNIX time indicating when the rating was made.
# - **title** (from `u.item`) – the name of the movie.
# - **genres** (from `u.item`) – one or more genres assigned to each movie (e.g., Action, Comedy).
#
# This dataset is small enough to allow fast experimentation, yet rich enough to demonstrate the strengths and weaknesses of different recommendation algorithms.

# %%
# !pip uninstall -y scikit-surprise
# !pip install numpy==1.26.4 --force-reinstall

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import zipfile
import pandas as pd

# Path to the ZIP file in Google Drive
zip_path = "/content/drive/MyDrive/Portfolio datasets/Recommender engine/ml-100k.zip"
extract_path = "/content/ml-100k"

# Extract the dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Load the ratings (u.data)
data_path = f"{extract_path}/ml-100k/u.data"
df = pd.read_csv(
    data_path,
    sep="\t",
    names=["userId", "movieId", "rating", "timestamp"]
)

# Load the movie titles (u.item)
item_path = f"{extract_path}/ml-100k/u.item"
movies = pd.read_csv(
    item_path,
    sep="|",
    encoding="latin-1",
    header=None,
    usecols=[0, 1],
    names=["movieId", "title"]
)

# Merge ratings with movie titles
df_merged = pd.merge(df, movies, on="movieId")

print("Data shape:", df_merged.shape)
print(df_merged.head())
# Out:
# Data shape: (100000, 5)
#    userId  movieId  rating  timestamp                       title
# 0     196      242       3  881250949                Kolya (1996)
# 1     186      302       3  891717742    L.A. Confidential (1997)
# 2      22      377       1  878887116         Heavyweights (1994)
# 3     244       51       2  880606923  Legends of the Fall (1994)
# 4     166      346       1  886397596         Jackie Brown (1997)

# %% [markdown]
# # NeuMF 5-Fold Cross-Validation: Code Overview
#
# ## What the code does
# This script trains and evaluates a **NeuMF (Neural Matrix Factorization)** recommender on MovieLens 100K using **5-fold cross-validation**, reporting both **RMSE** and **Top-K ranking metrics**.
#
# ## Data handling
# - Expects a pre-built `df_merged` with `userId`, `movieId`, `rating`.
# - Converts `userId`/`movieId` to zero-based indices.
# - Wraps samples in a `RatingsDataset` and uses PyTorch `DataLoader` for batching.
#
# ## Model architecture (NeuMF)
# - **GMF branch:** user/item embeddings with element-wise product to capture linear interactions.
# - **MLP branch:** separate user/item embeddings concatenated and passed through fully-connected layers (default hidden sizes: `[64, 32, 16]`) with ReLU.
# - **Fusion:** concatenation of GMF output and MLP output, followed by a final linear layer to predict a rating.
# - Default embedding sizes: `emb_size_gmf=32`, `emb_size_mlp=32`.
#
# ## Training setup
# - Optimizer: Adam (`lr=0.001`).
# - Loss: Mean Squared Error (predicting explicit ratings 1–5).
# - Epochs: `5` per fold.
# - Batch size: `512`.
# - For each fold, a **fresh NeuMF model is initialized**, trained, and evaluated.
#
# ## Evaluation
# - **RMSE** on the test split of each fold.
# - **Top-K metrics** computed by `metrics_at_k` for K ∈ {5, 10, 20}:
#   - Precision@K, Recall@K, F1@K
#   - NDCG@K
#   - HitRate@K
# - An item is considered **relevant** if `true_rating ≥ 4`.
# - The script prints per-fold results and then an aggregated mean across folds.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from collections import defaultdict

# === Dataset Wrapper ===
class RatingsDataset(Dataset):
    def __init__(self, df):
        self.users = torch.tensor(df["userId"].values, dtype=torch.long)
        self.items = torch.tensor(df["movieId"].values, dtype=torch.long)
        self.ratings = torch.tensor(df["rating"].values, dtype=torch.float32)

    def __len__(self):
        return len(self.ratings)

    def __getitem__(self, idx):
        return self.users[idx], self.items[idx], self.ratings[idx]

# === NeuMF Model ===
class NeuMF(nn.Module):
    def __init__(self, n_users, n_items, emb_size_gmf=32, emb_size_mlp=32, hidden=[64,32,16]):
        super(NeuMF, self).__init__()

        # GMF embeddings
        self.user_emb_gmf = nn.Embedding(n_users, emb_size_gmf)
        self.item_emb_gmf = nn.Embedding(n_items, emb_size_gmf)

        # MLP embeddings
        self.user_emb_mlp = nn.Embedding(n_users, emb_size_mlp)
        self.item_emb_mlp = nn.Embedding(n_items, emb_size_mlp)

        # MLP layers
        mlp_layers = []
        input_size = emb_size_mlp * 2
        for h in hidden:
            mlp_layers.append(nn.Linear(input_size, h))
            mlp_layers.append(nn.ReLU())
            input_size = h
        self.mlp = nn.Sequential(*mlp_layers)

        # Final prediction layer
        self.output = nn.Linear(emb_size_gmf + hidden[-1], 1)

    def forward(self, users, items):
        gmf_u = self.user_emb_gmf(users)
        gmf_i = self.item_emb_gmf(items)
        gmf = gmf_u * gmf_i

        mlp_u = self.user_emb_mlp(users)
        mlp_i = self.item_emb_mlp(items)
        mlp = self.mlp(torch.cat([mlp_u, mlp_i], dim=1))

        x = torch.cat([gmf, mlp], dim=1)
        return self.output(x).squeeze()

    def predict(self, users, items):
        self.eval()
        with torch.no_grad():
            return self.forward(users, items)


# === Helper: Top-K metrics ===
def metrics_at_k(users, items, ratings, preds, ks=[5,10,20]):
    user_ratings = defaultdict(list)
    for u, i, r, p in zip(users, items, ratings, preds):
        user_ratings[int(u)].append((i, p, r))

    results = {k: {"Precision": [], "Recall": [], "F1": [], "NDCG": [], "HitRate": []} for k in ks}

    for uid, ratings in user_ratings.items():
        ratings.sort(key=lambda x: x[1], reverse=True)
        rel = [r for (_, _, r) in ratings if r >= 4]
        n_rel = len(rel)

        for k in ks:
            top_k = ratings[:k]
            rec = [iid for (iid, _, r) in top_k if r >= 4]
            n_rel_and_rec_k = len(rec)

            precision = n_rel_and_rec_k / k if k > 0 else 0
            recall = n_rel_and_rec_k / n_rel if n_rel > 0 else 0
            f1 = (2*precision*recall / (precision+recall)) if (precision+recall)>0 else 0

            dcg = sum([1/np.log2(idx+2) for idx,(iid,_,r) in enumerate(top_k) if r>=4])
            idcg = sum([1/np.log2(idx+2) for idx in range(min(n_rel, k))])
            ndcg = dcg/idcg if idcg>0 else 0

            hit = 1 if n_rel_and_rec_k>0 else 0

            results[k]["Precision"].append(precision)
            results[k]["Recall"].append(recall)
            results[k]["F1"].append(f1)
            results[k]["NDCG"].append(ndcg)
            results[k]["HitRate"].append(hit)

    return {k: {m: np.mean(vals) for m, vals in metrics.items()} for k, metrics in results.items()}

# === Load ratings data (from df_merged) ===
ratings_df = df_merged[["userId", "movieId", "rating"]].copy()
ratings_df["userId"] -= 1
ratings_df["movieId"] -= 1

n_users = ratings_df["userId"].nunique()
n_items = ratings_df["movieId"].nunique()

# === 5-Fold Cross Validation ===
kf = KFold(n_splits=5, shuffle=True, random_state=42)
results = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for fold, (train_idx, test_idx) in enumerate(kf.split(ratings_df), 1):
    print(f"\n=== Fold {fold} ===")
    train_df = ratings_df.iloc[train_idx]
    test_df = ratings_df.iloc[test_idx]

    train_loader = DataLoader(RatingsDataset(train_df), batch_size=512, shuffle=True)
    test_loader = DataLoader(RatingsDataset(test_df), batch_size=512, shuffle=False)

    # Init new NeuMF each fold
    model = NeuMF(n_users, n_items).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Training
    epochs = 5
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for users, items, ratings in train_loader:
            users, items, ratings = users.to(device), items.to(device), ratings.to(device)
            optimizer.zero_grad()
            preds = model(users, items)
            loss = criterion(preds, ratings)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * len(ratings)
        print(f"  Epoch {epoch+1}/{epochs}, Train RMSE: {np.sqrt(train_loss/len(train_df)):.4f}")

    # Evaluation
    model.eval()
    test_preds, test_truth, test_users, test_items = [], [], [], []
    with torch.no_grad():
        for users, items, ratings in test_loader:
            users, items = users.to(device), items.to(device)
            preds = model(users, items).cpu().numpy()
            test_preds.extend(preds)
            test_truth.extend(ratings.numpy())
            test_users.extend(users.cpu().numpy())
            test_items.extend(items.cpu().numpy())

    rmse = np.sqrt(np.mean((np.array(test_preds) - np.array(test_truth))**2))
    print(f"  Fold {fold} RMSE: {rmse:.4f}")

    # Top-K
    metrics = metrics_at_k(test_users, test_items, test_truth, test_preds, ks=[5,10,20])

    row = {"Fold": fold, "RMSE": rmse}
    for k in [5,10,20]:
        for m,v in metrics[k].items():
            row[m+f"@{k}"] = v
    results.append(row)

# === Aggregate Results ===
results_df = pd.DataFrame(results)
print("\n=== NeuMF 5-Fold CV Results (Per Fold) ===")
print(results_df)

avg_results = results_df.mean(numeric_only=True)
print("\n=== NeuMF 5-Fold CV Results (Averaged) ===")
print(avg_results)
# Out:
# === Fold 1 ===
#   Epoch 1/5, Train RMSE: 2.0333
#   Epoch 2/5, Train RMSE: 1.0867
#   Epoch 3/5, Train RMSE: 1.0354
#   Epoch 4/5, Train RMSE: 1.0034
#   Epoch 5/5, Train RMSE: 0.9794
#   Fold 1 RMSE: 0.9935
#
# === Fold 2 ===
#   Epoch 1/5, Train RMSE: 2.1229
#   Epoch 2/5, Train RMSE: 1.0801
#   Epoch 3/5, Train RMSE: 1.0291
#   Epoch 4/5, Train RMSE: 0.9982
#   Epoch 5/5, Train RMSE: 0.9763
#   Fold 2 RMSE: 0.9891
#
# === Fold 3 ===
#   Epoch 1/5, Train RMSE: 2.0012
#   Epoch 2/5, Train RMSE: 1.0866
#   Epoch 3/5, Train RMSE: 1.0352
#   Epoch 4/5, Train RMSE: 1.0029
#   Epoch 5/5, Train RMSE: 0.9792
#   Fold 3 RMSE: 1.0066
#
# === Fold 4 ===
#   Epoch 1/5, Train RMSE: 2.0889
#   Epoch 2/5, Train RMSE: 1.0906
#   Epoch 3/5, Train RMSE: 1.0362
#   Epoch 4/5, Train RMSE: 1.0032
#   Epoch 5/5, Train RMSE: 0.9795
#   Fold 4 RMSE: 0.9961
#
# === Fold 5 ===
#   Epoch 1/5, Train RMSE: 2.0578
#   Epoch 2/5, Train RMSE: 1.0911
#   Epoch 3/5, Train RMSE: 1.0407
#   Epoch 4/5, Train RMSE: 1.0084
#   Epoch 5/5, Train RMSE: 0.9846
#   Fold 5 RMSE: 1.0026
#
# === NeuMF 5-Fold CV Results (Per Fold) ===
#    Fold      RMSE  Precision@5  Recall@5      F1@5    NDCG@5  HitRate@5  \
# 0     1  0.993471     0.662340  0.498266  0.473686  0.768465   0.969149
# 1     2  0.989085     0.677707  0.511927  0.488146  0.786441   0.974522
# 2     3  1.006630     0.669427  0.503918  0.481041  0.777986   0.966030
# 3     4  0.996055     0.672264  0.502774  0.481002  0.771307   0.974495
# 4     5  1.002646     0.676383  0.509233  0.488325  0.780344   0.976596
#
#    Precision@10  Recall@10     F1@10   NDCG@10  HitRate@10  Precision@20  \
# 0      0.554574   0.698088  0.520779  0.791251    0.976596      0.409043
# 1      0.553609   0.700144  0.521139  0.801783    0.979830      0.413854
# 2      0.556051   0.700012  0.522559  0.799066    0.973461      0.408333
# 3      0.561530   0.700689  0.526139  0.795067    0.981934      0.415675
# 4      0.565532   0.708925  0.533696  0.805879    0.981915      0.415585
#
#    Recall@20     F1@20   NDCG@20  HitRate@20
# 0   0.851827  0.474850  0.817413    0.978723
# 1   0.857448  0.479105  0.829240    0.979830
# 2   0.850063  0.472815  0.823480    0.974522
# 3   0.856291  0.481211  0.822190    0.981934
# 4   0.859979  0.483057  0.831329    0.982979
#
# === NeuMF 5-Fold CV Results (Averaged) ===
# Fold            3.000000
# RMSE            0.997577
# Precision@5     0.671624
# Recall@5        0.505224
# F1@5            0.482440
# NDCG@5          0.776908
# HitRate@5       0.972158
# Precision@10    0.558259
# Recall@10       0.701572
# F1@10           0.524862
# NDCG@10         0.798609
# HitRate@10      0.978747
# Precision@20    0.412498
# Recall@20       0.855121
# F1@20           0.478208
# NDCG@20         0.824731
# HitRate@20      0.979598
# dtype: float64

# %%
# !pip install bitsandbytes accelerate transformers langgraph

# %%
import os
os.environ["HF_TOKEN"] = "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"

# %%
# === Open Source Granite 8B model LLM ===
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
import torch

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    llm_int8_enable_fp32_cpu_offload=True
)
try:
    # Granite 8B model name on Hugging Face
    GRANITE_MODEL = "ibm-granite/granite-3.3-8b-instruct"

    # Load the model + tokenizer
    granite_model = AutoModelForCausalLM.from_pretrained(
        GRANITE_MODEL,
        device_map="auto",
        quantization_config=bnb_config  # Optional
    )

    granite_tokenizer = AutoTokenizer.from_pretrained(GRANITE_MODEL)

    # Create pipeline
    granite_pipe = pipeline(
        "text-generation",
        model=granite_model,
        tokenizer=granite_tokenizer,
        pad_token_id=granite_tokenizer.eos_token_id,
        return_full_text=False
    )
except Exception as e:
    print("[Warning] Failed to load LLaMA model:", e)
    granite_pipe = lambda prompt, **kwargs: [{"generated_text": "[granit model unavailable]"}]
granite_pipe = pipeline("text-generation", model=granite_model, tokenizer=granite_tokenizer)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Use the ratings dataframe (already loaded from MovieLens or another dataset)
ratings_df = df_merged[["userId", "movieId", "rating"]].copy()

# Train/Test split
train_df, test_df = train_test_split(ratings_df, test_size=0.2, random_state=42)

# Build ratings_history from train_df
ratings_history = (
    train_df.groupby("userId")[["movieId", "rating"]]
    .apply(lambda g: list(zip(g["movieId"], g["rating"])))
    .to_dict()
)

# Build item_pool from all unique movies
item_pool = ratings_df["movieId"].unique().tolist()

print("Data prepared:")
print(f"Train size: {len(train_df)}, Test size: {len(test_df)}")
print(f"Number of users in train: {train_df['userId'].nunique()}")
print(f"Number of items in pool: {len(item_pool)}")
# Out:
# Data prepared:
# Train size: 80000, Test size: 20000
# Number of users in train: 943
# Number of items in pool: 1682

# %%
# === AI Agents with LangGraph, using pre-trained SVD++ and MovieLens titles/genres ===
import pandas as pd
from langgraph.graph import StateGraph, END
from typing import TypedDict
import re
from collections import Counter
from itertools import combinations

from transformers.utils import logging
logging.set_verbosity_error()


# 1) Load movies with titles + genres
movies_df = pd.read_csv(
    "/content/ml-100k/ml-100k/u.item",
    sep="|",
    encoding="latin-1",
    header=None,
    names=["movieId", "title", "release_date", "video_release_date", "IMDb_URL",
           "unknown", "Action", "Adventure", "Animation", "Children's", "Comedy",
           "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror",
           "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
)

def clean_title(title: str) -> str:
    return re.sub(r"\s*\(\d{4}\)$", "", title)

genre_cols = movies_df.columns[5:]
movies_df["genres"] = movies_df[genre_cols].apply(
    lambda row: ", ".join([g for g, v in row.items() if v == 1]), axis=1
)

# 2) Merge ratings with movie metadata
ratings_full = df_merged[["userId", "movieId", "rating"]].merge(
    movies_df[["movieId", "title", "genres"]],
    on="movieId", how="left"
)

item_pool = ratings_full["movieId"].unique().tolist()
ratings_history = (
    ratings_full.groupby("userId")[["movieId", "rating"]]
    .apply(lambda x: list(zip(x["movieId"], x["rating"])) )
    .to_dict()
)

movie_titles = ratings_full.set_index("movieId")["title"].to_dict()
movie_genres = ratings_full.set_index("movieId")["genres"].to_dict()

def title_of(iid: int) -> str:
    return movie_titles.get(iid, "Unknown title")

def genres_of(iid: int) -> str:
    g = movie_genres.get(iid, "")
    return g if isinstance(g, str) and g else "Unknown genre"

# 3) State definition
class State(TypedDict):
    user_id: int
    request: str
    recommendations: list
    explanation: str
    critique: str

# === Build mapping from original IDs to continuous indices ===
unique_movie_ids = sorted(df_merged["movieId"].unique())
movie2idx = {mid: idx for idx, mid in enumerate(unique_movie_ids)}
idx2movie = {idx: mid for mid, idx in movie2idx.items()}
df_merged["movieId"] = df_merged["movieId"].map(movie2idx)
movies_df["movieId"] = movies_df["movieId"].map(movie2idx)

unique_user_ids = sorted(df_merged["userId"].unique())
user2idx = {uid: idx for idx, uid in enumerate(unique_user_ids)}
idx2user = {idx: uid for uid, idx in user2idx.items()}
df_merged["userId"] = df_merged["userId"].map(user2idx)

# Drop rows with missing values (if any)
df_merged.dropna(subset=["userId", "movieId"], inplace=True)
df_merged["userId"] = df_merged["userId"].astype(int)
df_merged["movieId"] = df_merged["movieId"].astype(int)
movies_df.dropna(subset=["movieId"], inplace=True)
movies_df["movieId"] = movies_df["movieId"].astype(int)

# 4) RecommenderAgent for PyTorch-based NeuMF
class RecommenderAgent:
    def __init__(self, model, movies_df, device, idx2movie=None):
        """
        Initialize the recommendation agent.

        Args:
            model (nn.Module): Trained PyTorch NeuMF model.
            movies_df (pd.DataFrame): Movie metadata with 'movieId', 'title', 'genres'.
            device (torch.device): Device to run the model on ('cuda' or 'cpu').
            idx2movie (dict, optional): Mapping from internal movie indices back to original movieIds.
        """
        self.model = model
        self.movies_df = movies_df
        self.device = device
        self.idx2movie = idx2movie

    def recommend(self, user_id, item_pool, top_k=20):
        """
        Generate top-K movie recommendations for a specific user.

        Args:
            user_id (int): Internal user ID (after mapping to 0-based index).
            item_pool (list[int]): List of candidate internal movie IDs to consider.
            top_k (int): Number of top recommendations to return.

        Returns:
            pd.DataFrame: DataFrame with columns: title, genres, predicted_rating.
        """
        # Validate user and item indices
        max_user_id = self.model.user_emb_gmf.num_embeddings
        max_item_id = self.model.item_emb_gmf.num_embeddings
        assert 0 <= user_id < max_user_id, f"Invalid user_id: {user_id} (max allowed: {max_user_id - 1})"
        assert all(0 <= i < max_item_id for i in item_pool), "item_pool contains invalid movieId values"

        # Convert user and items to tensors
        user_tensor = torch.tensor([user_id] * len(item_pool), dtype=torch.long).to(self.device)
        item_tensor = torch.tensor(item_pool, dtype=torch.long).to(self.device)

        # Generate predictions
        self.model.eval()
        with torch.no_grad():
            preds = self.model(user_tensor, item_tensor).cpu().numpy()

        # Pair items with predictions and sort
        preds = list(zip(item_pool, preds))
        preds = sorted(preds, key=lambda x: x[1], reverse=True)[:top_k]

        # Build result DataFrame
        recs_df = pd.DataFrame(preds, columns=["movieId", "predicted_rating"])
        recs_df = recs_df.merge(self.movies_df, on="movieId", how="left")

        # Optional: map back to original movieId
        if self.idx2movie is not None:
            recs_df["movieId_original"] = recs_df["movieId"].map(self.idx2movie)

        return recs_df[["title", "genres", "predicted_rating"]]

    def run(self, state, item_pool, top_k=20):
        """
        Run recommendation for a given user and update the state dictionary.

        Args:
            state (dict): Dictionary containing at least the key 'user_id'.
            item_pool (list[int]): List of internal movie IDs to recommend from.
            top_k (int): Number of top recommendations to generate.

        Returns:
            dict: Updated state with a 'recommendations' DataFrame.
        """
        user_id = state["user_id"]
        recs = self.recommend(user_id, item_pool, top_k)
        state["recommendations"] = recs

        print("--- Top-{} recommendations before re-ranking ---".format(top_k))
        for i, row in enumerate(recs.itertuples(), 1):
            print(f"{i}. {row.title} ({row.genres}) → pred {row.predicted_rating:.2f}")

        return state



# 5) CritiqueAgent
def wrap_text(text, words_per_line=10):
    words = text.split()
    lines = [" ".join(words[i:i+words_per_line]) for i in range(0, len(words), words_per_line)]
    return "\n".join(lines)

class CritiqueAgent:
    def __init__(self, pipe, words_per_line=10):
        self.pipe = pipe
        self.words_per_line = words_per_line

    def run(self, state):
        recs = state["recommendations"]
        recs_str = "; ".join(
            f"{row['title']} ({row['genres']}) pred {row['predicted_rating']:.2f}"
            for _, row in recs.iterrows()
        )
        prompt = (
            "You are a movie recommendation critic. Based on the following recommended list, "
            "write a brief critique of possible weaknesses in the recommendation strategy. "
            "Focus on thematic richness, emotional depth, genre variety (e.g. missing musical, children's, animation), "
            "and suggest one possible improvement in no more than 3 lines.\n\n"
            f"Recommendations: {recs_str}\n\n"
            "Critique:"
        )
        out = self.pipe(prompt, max_new_tokens=100, temperature=0.6)[0]["generated_text"]
        if "Critique:" in out:
            out = out.split("Critique:")[-1].strip()
        return {"critique": wrap_text(out, self.words_per_line)}

# 6) DiversityRerankerAgent
class DiversityRerankerAgent:
    def __init__(self, top_k=5, diversity_weight=1.0):
        self.top_k = top_k
        self.diversity_weight = diversity_weight

    def compute_genre_bonus(self, selected_genres, candidate_genres):
        """Calculate how many new genres this candidate adds."""
        candidate_set = set(candidate_genres.split(", "))
        return len(candidate_set - selected_genres)

    def run(self, state):
        recs = state["recommendations"].copy()
        if len(recs) <= self.top_k:
            return state

        # Select top_k movies incrementally to maximize genre diversity + rating
        selected = []
        selected_genres = set()
        remaining = recs.copy()

        while len(selected) < self.top_k and not remaining.empty:
            def score(row):
                genre_bonus = self.compute_genre_bonus(selected_genres, row["genres"])
                return (1 - self.diversity_weight) * row["predicted_rating"] + self.diversity_weight * genre_bonus

            remaining["score"] = remaining.apply(score, axis=1)
            best = remaining.sort_values(by="score", ascending=False).iloc[0]
            selected.append(best)
            selected_genres.update(best["genres"].split(", "))
            remaining = remaining.drop(best.name)

        state["recommendations"] = pd.DataFrame(selected)[["title", "genres", "predicted_rating"]].reset_index(drop=True)
        return state


# 7) Graph builder
def build_graph(recommender, diversity_reranker, critique_agent, item_pool):
    graph = StateGraph(State)
    graph.add_node("Recommender", lambda s: recommender.run(s, item_pool, top_k=20))
    graph.add_node("DiversityReranker", lambda s: diversity_reranker.run(s))
    graph.add_node("Critique", lambda s: critique_agent.run(s))

    graph.add_edge("Recommender", "DiversityReranker")
    graph.add_edge("DiversityReranker", "Critique")
    graph.add_edge("Critique", END)

    graph.set_entry_point("Recommender")
    return graph

# 8) History printer
def print_user_history(user_id: int, ratings_df: pd.DataFrame, max_items=10):
    print("\n--- User History ---")
    df = ratings_df[ratings_df["userId"] == user_id][["title", "genres", "rating"]].copy()
    df["title"] = df["title"].fillna("Unknown title").apply(clean_title)
    df = df.sort_values(by=["rating", "title"], ascending=[False, True]).head(max_items)
    print(df.to_string(index=False))

# 9) Initialize agents
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#recommender = RecommenderAgent(model, movies_df, device)
recommender = RecommenderAgent(model, movies_df, device, idx2movie=idx2movie)


diversity_reranker = DiversityRerankerAgent(top_k=5, diversity_weight=1.5)
critique_agent = CritiqueAgent(granite_pipe, words_per_line=10)

graph = build_graph(recommender, diversity_reranker, critique_agent, item_pool)
app = graph.compile()

# 10) Run example
sample_users = ratings_full["userId"].drop_duplicates().sample(n=10, random_state=42)
for uid in sample_users:
    print_user_history(uid, ratings_full)
    result = app.invoke({"user_id": int(uid), "request": "Recommend me movies"})

    print("\n=== Dialogue Agent Output ===")
    print(f"User: {uid}")
    print("\nCritique:")
    print(result["critique"])
    print("\nDiversityReranker:")
    print(result["recommendations"])
# Out:
# --- User History ---
#                          title                      genres  rating
#                       Anaconda Action, Adventure, Thriller       5
#          Browning Version, The                       Drama       5
#      In the Name of the Father                       Drama       5
#                    Kansas City                       Crime       5
#                   My Fair Lady            Musical, Romance       5
#              Santa Clause, The          Children's, Comedy       5
#       Sex, Lies, and Videotape                       Drama       5
#                   12 Angry Men                       Drama       4
#                 Absolute Power           Mystery, Thriller       4
# Ace Ventura: When Nature Calls                      Comedy       4
# --- Top-20 recommendations before re-ranking ---
# 1. Quartier Mozart (1992) (Comedy) → pred 4.55
# 2. Tin Cup (1996) (Comedy, Romance) → pred 4.32
# 3. Monty Python and the Holy Grail (1974) (Comedy) → pred 4.30
# 4. Spy Hard (1996) (Comedy) → pred 4.27
# 5. Some Like It Hot (1959) (Comedy, Crime) → pred 4.23
# 6. Father of the Bride Part II (1995) (Comedy) → pred 4.19
# 7. In & Out (1997) (Comedy) → pred 4.18
# 8. Around the World in 80 Days (1956) (Adventure, Comedy) → pred 4.18
# 9. Dead Poets Society (1989) (Drama) → pred 4.15
# 10. I.Q. (1994) (Comedy, Romance) → pred 4.14
# 11. Midnight in the Garden of Good and Evil (1997) (Comedy, Crime, Drama, Mystery) → pred 4.14
# 12. Transformers: The Movie, The (1986) (Action, Animation, Children's, Sci-Fi, Thriller, War) → pred 4.13
# 13. Delicatessen (1991) (Comedy, Sci-Fi) → pred 4.13
# 14. Cook the Thief His Wife & Her Lover, The (1989) (Drama) → pred 4.12
# 15. Butcher Boy, The (1998) (Drama) → pred 4.11
# 16. Client, The (1994) (Drama, Mystery, Thriller) → pred 4.10
# 17. M (1931) (Crime, Film-Noir, Thriller) → pred 4.09
# 18. Seven (Se7en) (1995) (Crime, Thriller) → pred 4.07
# 19. Waterworld (1995) (Action, Adventure) → pred 4.07
# 20. American in Paris, An (1951) (Musical, Romance) → pred 4.06
#
# === Dialogue Agent Output ===
# User: 261
#
# Critique:
# The current recommendation strategy appears to favor action-oriented films, with
# a notable absence of musicals and children's films. The thematic
# richness is somewhat limited, primarily focusing on crime, thriller, and
# action genres. Emotional depth, while present in films like Midnight
# in the Garden of Good and Evil, could be enhanced
# by incorporating more diverse genres and emotional resonance, such as
# a heartwarming mus
#
# DiversityReranker:
#                                             title  \
# 0             Transformers: The Movie, The (1986)
# 1  Midnight in the Garden of Good and Evil (1997)
# 2                    American in Paris, An (1951)
# 3                               Waterworld (1995)
# 4                                        M (1931)
#
#                                               genres  predicted_rating
# 0  Action, Animation, Children's, Sci-Fi, Thrille...          4.130785
# 1                      Comedy, Crime, Drama, Mystery          4.135370
# 2                                   Musical, Romance          4.060932
# 3                                  Action, Adventure          4.066193
# 4                         Crime, Film-Noir, Thriller          4.087315
#
# --- User History ---
#                                    title                            genres  rating
#                               Annie Hall                   Comedy, Romance       5
#                                     Babe         Children's, Comedy, Drama       5
#                              Chasing Amy                    Drama, Romance       5
#                Crow: City of Angels, The                  Action, Thriller       5
#                         Frighteners, The                    Comedy, Horror       5
#                      Great Dictator, The                            Comedy       5
# Haunted World of Edward D. Wood Jr., The                       Documentary       5
#                In the Name of the Father                             Drama       5
#                             Men in Black Action, Adventure, Comedy, Sci-Fi       5
#                         Mighty Aphrodite                            Comedy       5
# --- Top-20 recommendations before re-ranking ---
# 1. Quartier Mozart (1992) (Comedy) → pred 4.87
# 2. Butcher Boy, The (1998) (Drama) → pred 4.80
# 3. Some Like It Hot (1959) (Comedy, Crime) → pred 4.68
# 4. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.66
# 5. Delicatessen (1991) (Comedy, Sci-Fi) → pred 4.63
# 6. Tin Cup (1996) (Comedy, Romance) → pred 4.62
# 7. M (1931) (Crime, Film-Noir, Thriller) → pred 4.61
# 8. Midnight in the Garden of Good and Evil (1997) (Comedy, Crime, Drama, Mystery) → pred 4.53
# 9. Snow White and the Seven Dwarfs (1937) (Animation, Children's, Musical) → pred 4.52
# 10. I.Q. (1994) (Comedy, Romance) → pred 4.52
# 11. Pushing Hands (1992) (Comedy) → pred 4.52
# 12. Henry V (1989) (Drama, War) → pred 4.49
# 13. Bringing Up Baby (1938) (Comedy) → pred 4.49
# 14. Muppet Treasure Island (1996) (Action, Adventure, Comedy, Musical, Thriller) → pred 4.47
# 15. 2001: A Space Odyssey (1968) (Drama, Mystery, Sci-Fi, Thriller) → pred 4.47
# 16. James and the Giant Peach (1996) (Animation, Children's, Musical) → pred 4.47
# 17. Beauty and the Beast (1991) (Animation, Children's, Musical) → pred 4.47
# 18. Unbearable Lightness of Being, The (1988) (Drama) → pred 4.47
# 19. Roman Holiday (1953) (Comedy, Romance) → pred 4.46
# 20. In & Out (1997) (Comedy) → pred 4.46
#
# === Dialogue Agent Output ===
# User: 135
#
# Critique:
# The recommendation list lacks thematic diversity and emotional depth, relying
# heavily on adventure and thriller genres. The absence of a
# musical and children's film suggests a potential oversight in catering
# to a broader audience spectrum. Including a classic musical like
# "Singin' in the Rain" or a contemporary children's film such
# as "Coco" could enrich the list by appealing to a
# wider range of viewers and emotions
#
# DiversityReranker:
#                            title  \
# 0  Muppet Treasure Island (1996)
# 1   2001: A Space Odyssey (1968)
# 2    Beauty and the Beast (1991)
# 3                       M (1931)
# 4           Roman Holiday (1953)
#
#                                          genres  predicted_rating
# 0  Action, Adventure, Comedy, Musical, Thriller          4.473122
# 1              Drama, Mystery, Sci-Fi, Thriller          4.471311
# 2                Animation, Children's, Musical          4.468023
# 3                    Crime, Film-Noir, Thriller          4.607104
# 4                               Comedy, Romance          4.462941
#
# --- User History ---
#                  title                    genres  rating
#       Albino Alligator           Crime, Thriller       5
#               Bad Boys                    Action       5
#               Bad Moon                    Horror       5
#  Beverly Hills Cop III            Action, Comedy       5
# Breakfast at Tiffany's            Drama, Romance       5
#             Casablanca       Drama, Romance, War       5
#           Citizen Ruth             Comedy, Drama       5
#            Client, The  Drama, Mystery, Thriller       5
#    Clockwork Orange, A                    Sci-Fi       5
#     Dances with Wolves Adventure, Drama, Western       5
# --- Top-20 recommendations before re-ranking ---
# 1. Father of the Bride Part II (1995) (Comedy) → pred 4.98
# 2. Quartier Mozart (1992) (Comedy) → pred 4.92
# 3. Monty Python and the Holy Grail (1974) (Comedy) → pred 4.90
# 4. Breakfast at Tiffany's (1961) (Drama, Romance) → pred 4.88
# 5. Vertigo (1958) (Mystery, Thriller) → pred 4.88
# 6. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.85
# 7. Free Willy (1993) (Adventure, Children's, Drama) → pred 4.84
# 8. James and the Giant Peach (1996) (Animation, Children's, Musical) → pred 4.81
# 9. Spy Hard (1996) (Comedy) → pred 4.79
# 10. Ed Wood (1994) (Comedy, Drama) → pred 4.77
# 11. Alien: Resurrection (1997) (Action, Horror, Sci-Fi) → pred 4.77
# 12. Balto (1995) (Animation, Children's) → pred 4.76
# 13. Kaspar Hauser (1993) (Drama) → pred 4.75
# 14. Annie Hall (1977) (Comedy, Romance) → pred 4.73
# 15. Amateur (1994) (Crime, Drama, Thriller) → pred 4.72
# 16. African Queen, The (1951) (Action, Adventure, Romance, War) → pred 4.72
# 17. Some Like It Hot (1959) (Comedy, Crime) → pred 4.72
# 18. Delicatessen (1991) (Comedy, Sci-Fi) → pred 4.70
# 19. Young Frankenstein (1974) (Comedy, Horror) → pred 4.70
# 20. M (1931) (Crime, Film-Noir, Thriller) → pred 4.69
#
# === Dialogue Agent Output ===
# User: 820
#
# Critique:
# The current recommendations lack thematic richness, as they primarily focus
# on classic genres like adventure, crime, and comedy, with limited
# exploration of other themes such as drama, historical, or contemporary
# social issues. Emotional depth is also underrepresented, with most films
# offering light-hearted entertainment rather than thought-provoking narratives. The genre variety
# is somewhat addressed with the inclusion of a children's musical,
# but there
#
# DiversityReranker:
#                               title                           genres  \
# 0         African Queen, The (1951)  Action, Adventure, Romance, War
# 1                          M (1931)       Crime, Film-Noir, Thriller
# 2  James and the Giant Peach (1996)   Animation, Children's, Musical
# 3         Young Frankenstein (1974)                   Comedy, Horror
# 4               Delicatessen (1991)                   Comedy, Sci-Fi
#
#    predicted_rating
# 0          4.720098
# 1          4.692413
# 2          4.812864
# 3          4.700592
# 4          4.702311
#
# --- User History ---
#                           title                        genres  rating
# Aladdin and the King of Thieves Animation, Children's, Comedy       5
#                          Aliens Action, Sci-Fi, Thriller, War       5
#                         Amadeus                Drama, Mystery       5
#           American in Paris, An              Musical, Romance       5
#                  Apartment, The                 Comedy, Drama       5
#                     Being There                        Comedy       5
#               Bloody Child, The               Drama, Thriller       5
#             Blues Brothers, The       Action, Comedy, Musical       5
#           Bram Stoker's Dracula               Horror, Romance       5
#                      Braveheart            Action, Drama, War       5
# --- Top-20 recommendations before re-ranking ---
# 1. Quartier Mozart (1992) (Comedy) → pred 4.91
# 2. Butcher Boy, The (1998) (Drama) → pred 4.77
# 3. Muppet Treasure Island (1996) (Action, Adventure, Comedy, Musical, Thriller) → pred 4.62
# 4. Farewell to Arms, A (1932) (Romance, War) → pred 4.59
# 5. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.57
# 6. Spy Hard (1996) (Comedy) → pred 4.54
# 7. Free Willy (1993) (Adventure, Children's, Drama) → pred 4.53
# 8. Metisse (Café au Lait) (1993) (Comedy) → pred 4.50
# 9. American in Paris, An (1951) (Musical, Romance) → pred 4.49
# 10. Henry V (1989) (Drama, War) → pred 4.47
# 11. Santa Clause, The (1994) (Children's, Comedy) → pred 4.47
# 12. Annie Hall (1977) (Comedy, Romance) → pred 4.44
# 13. Some Like It Hot (1959) (Comedy, Crime) → pred 4.43
# 14. American Strays (1996) (Action) → pred 4.43
# 15. Tin Cup (1996) (Comedy, Romance) → pred 4.43
# 16. 2001: A Space Odyssey (1968) (Drama, Mystery, Sci-Fi, Thriller) → pred 4.42
# 17. Graduate, The (1967) (Drama, Romance) → pred 4.42
# 18. Delicatessen (1991) (Comedy, Sci-Fi) → pred 4.41
# 19. Sleepless in Seattle (1993) (Comedy, Romance) → pred 4.41
# 20. Cook the Thief His Wife & Her Lover, The (1989) (Drama) → pred 4.41
#
# === Dialogue Agent Output ===
# User: 307
#
# Critique:
# The current recommendation strategy exhibits a notable lack of thematic
# richness, primarily due to its overreliance on a few dominant
# genres such as action-adventure, sci-fi, and romance/war narratives. This narrow
# scope may fail to engage diverse audience preferences, particularly those
# seeking lighter or more whimsical content. The absence of musicals,
# children's films, and animations indicates a missed opportunity to cater
#
# DiversityReranker:
#                            title  \
# 0  Muppet Treasure Island (1996)
# 1   2001: A Space Odyssey (1968)
# 2     Farewell to Arms, A (1932)
# 3        Some Like It Hot (1959)
# 4       Santa Clause, The (1994)
#
#                                          genres  predicted_rating
# 0  Action, Adventure, Comedy, Musical, Thriller          4.616883
# 1              Drama, Mystery, Sci-Fi, Thriller          4.424049
# 2                                  Romance, War          4.594724
# 3                                 Comedy, Crime          4.431952
# 4                            Children's, Comedy          4.470003
#
# --- User History ---
#                       title                                 genres  rating
#              101 Dalmatians                     Children's, Comedy       5
#                     Aladdin Animation, Children's, Comedy, Musical       5
#     American President, The                 Comedy, Drama, Romance       5
#              Apocalypse Now                             Drama, War       5
# Around the World in 80 Days                      Adventure, Comedy       5
#     Bastard Out of Carolina                                  Drama       5
#                 Chasing Amy                         Drama, Romance       5
#                      Clerks                                 Comedy       5
#                 Client, The               Drama, Mystery, Thriller       5
#           Cold Comfort Farm                                 Comedy       5
# --- Top-20 recommendations before re-ranking ---
# 1. Some Like It Hot (1959) (Comedy, Crime) → pred 4.74
# 2. Spy Hard (1996) (Comedy) → pred 4.66
# 3. Quartier Mozart (1992) (Comedy) → pred 4.56
# 4. In the Name of the Father (1993) (Drama) → pred 4.44
# 5. In & Out (1997) (Comedy) → pred 4.44
# 6. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.43
# 7. Transformers: The Movie, The (1986) (Action, Animation, Children's, Sci-Fi, Thriller, War) → pred 4.37
# 8. Metisse (Café au Lait) (1993) (Comedy) → pred 4.33
# 9. American in Paris, An (1951) (Musical, Romance) → pred 4.33
# 10. Client, The (1994) (Drama, Mystery, Thriller) → pred 4.33
# 11. It's a Wonderful Life (1946) (Drama) → pred 4.31
# 12. Santa Clause, The (1994) (Children's, Comedy) → pred 4.28
# 13. Last of the Mohicans, The (1992) (Action, Romance, War) → pred 4.28
# 14. Unbearable Lightness of Being, The (1988) (Drama) → pred 4.26
# 15. Tin Cup (1996) (Comedy, Romance) → pred 4.26
# 16. Princess Bride, The (1987) (Action, Adventure, Comedy, Romance) → pred 4.25
# 17. Delicatessen (1991) (Comedy, Sci-Fi) → pred 4.25
# 18. James and the Giant Peach (1996) (Animation, Children's, Musical) → pred 4.24
# 19. Free Willy (1993) (Adventure, Children's, Drama) → pred 4.23
# 20. Father of the Bride Part II (1995) (Comedy) → pred 4.23
#
# === Dialogue Agent Output ===
# User: 300
#
# Critique:
# The recommendation list appears to favor action-oriented films with a
# predominant leaning towards sci-fi and thriller genres, overlooking the emotional
# depth that other genres such as romance, musicals, or dramas
# can provide. The absence of musicals and children's films outside
# of animation suggests a narrow thematic focus. A possible improvement
# could be incorporating a diverse range of genres, including a
# classic romantic comedy or a crit
#
# DiversityReranker:
#                                  title  \
# 0  Transformers: The Movie, The (1986)
# 1           Princess Bride, The (1987)
# 2                   Client, The (1994)
# 3     James and the Giant Peach (1996)
# 4              Some Like It Hot (1959)
#
#                                               genres  predicted_rating
# 0  Action, Animation, Children's, Sci-Fi, Thrille...          4.369587
# 1                 Action, Adventure, Comedy, Romance          4.249493
# 2                           Drama, Mystery, Thriller          4.330825
# 3                     Animation, Children's, Musical          4.241029
# 4                                      Comedy, Crime          4.741285
#
# --- User History ---
#                     title                              genres  rating
#                     8 1/2                               Drama       5
#            Absolute Power                   Mystery, Thriller       5
#                      Babe           Children's, Comedy, Drama       5
#         Dolores Claiborne                     Drama, Thriller       5
#                  In & Out                              Comedy       5
# In the Name of the Father                               Drama       5
#        Kicked in the Head                       Comedy, Drama       5
#         L.A. Confidential Crime, Film-Noir, Mystery, Thriller       5
# Last of the Mohicans, The                Action, Romance, War       5
#                  Mad City                       Action, Drama       5
# --- Top-20 recommendations before re-ranking ---
# 1. Quartier Mozart (1992) (Comedy) → pred 4.47
# 2. U.S. Marshalls (1998) (Action, Thriller) → pred 4.35
# 3. Star Trek: First Contact (1996) (Action, Adventure, Sci-Fi) → pred 4.34
# 4. Cook the Thief His Wife & Her Lover, The (1989) (Drama) → pred 4.33
# 5. Santa Clause, The (1994) (Children's, Comedy) → pred 4.27
# 6. Henry V (1989) (Drama, War) → pred 4.27
# 7. American in Paris, An (1951) (Musical, Romance) → pred 4.26
# 8. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.25
# 9. 2001: A Space Odyssey (1968) (Drama, Mystery, Sci-Fi, Thriller) → pred 4.23
# 10. Farewell to Arms, A (1932) (Romance, War) → pred 4.22
# 11. Metisse (Café au Lait) (1993) (Comedy) → pred 4.21
# 12. Grand Day Out, A (1992) (Animation, Comedy) → pred 4.21
# 13. Delicatessen (1991) (Comedy, Sci-Fi) → pred 4.20
# 14. Twelve Monkeys (1995) (Drama, Sci-Fi) → pred 4.18
# 15. Tin Cup (1996) (Comedy, Romance) → pred 4.18
# 16. Empire Strikes Back, The (1980) (Action, Adventure, Drama, Romance, Sci-Fi, War) → pred 4.17
# 17. Dances with Wolves (1990) (Adventure, Drama, Western) → pred 4.15
# 18. Sleepless in Seattle (1993) (Comedy, Romance) → pred 4.15
# 19. Butcher Boy, The (1998) (Drama) → pred 4.15
# 20. Annie Hall (1977) (Comedy, Romance) → pred 4.13
#
# === Dialogue Agent Output ===
# User: 203
#
# Critique:
# The recommendation strategy seems to favor a narrow range of
# genres, predominantly action, adventure, drama, sci-fi, and western, with a
# single musical and animation. This lack of variety in genre
# representation could limit the user's exposure to a broader emotional
# range and thematic depth. For instance, the absence of genres
# like comedy, horror, or historical dramas might not cater to
# diverse user preferences. A possible improvement
#
# DiversityReranker:
#                              title  \
# 0  Empire Strikes Back, The (1980)
# 1          Grand Day Out, A (1992)
# 2     2001: A Space Odyssey (1968)
# 3        Dances with Wolves (1990)
# 4     American in Paris, An (1951)
#
#                                            genres  predicted_rating
# 0  Action, Adventure, Drama, Romance, Sci-Fi, War          4.166161
# 1                               Animation, Comedy          4.211330
# 2                Drama, Mystery, Sci-Fi, Thriller          4.232275
# 3                       Adventure, Drama, Western          4.152998
# 4                                Musical, Romance          4.257163
#
# --- User History ---
#                                         title               genres  rating
#                                  Forrest Gump Comedy, Romance, War       5
#      Once Upon a Time... When We Were Colored                Drama       5
# Shanghai Triad (Yao a yao yao dao waipo qiao)                Drama       5
#                                Third Man, The    Mystery, Thriller       5
#                                Apocalypse Now           Drama, War       4
#                                  Citizen Ruth        Comedy, Drama       4
#                              Forbidden Planet               Sci-Fi       4
#                              Frighteners, The       Comedy, Horror       4
#                         Great White Hype, The               Comedy       4
#                                          I.Q.      Comedy, Romance       4
# --- Top-20 recommendations before re-ranking ---
# 1. Quartier Mozart (1992) (Comedy) → pred 4.47
# 2. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.35
# 3. Sleepless in Seattle (1993) (Comedy, Romance) → pred 4.13
# 4. In & Out (1997) (Comedy) → pred 4.11
# 5. Father of the Bride Part II (1995) (Comedy) → pred 4.10
# 6. Some Like It Hot (1959) (Comedy, Crime) → pred 4.10
# 7. James and the Giant Peach (1996) (Animation, Children's, Musical) → pred 4.08
# 8. I.Q. (1994) (Comedy, Romance) → pred 4.06
# 9. Delicatessen (1991) (Comedy, Sci-Fi) → pred 4.06
# 10. Kaspar Hauser (1993) (Drama) → pred 4.02
# 11. Princess Bride, The (1987) (Action, Adventure, Comedy, Romance) → pred 4.01
# 12. Henry V (1989) (Drama, War) → pred 3.96
# 13. Cook the Thief His Wife & Her Lover, The (1989) (Drama) → pred 3.95
# 14. Spitfire Grill, The (1996) (Drama) → pred 3.94
# 15. Monty Python and the Holy Grail (1974) (Comedy) → pred 3.94
# 16. Santa Clause, The (1994) (Children's, Comedy) → pred 3.93
# 17. Blues Brothers, The (1980) (Action, Comedy, Musical) → pred 3.93
# 18. Tin Cup (1996) (Comedy, Romance) → pred 3.93
# 19. Star Trek: First Contact (1996) (Action, Adventure, Sci-Fi) → pred 3.92
# 20. Casablanca (1942) (Drama, Romance, War) → pred 3.91
#
# === Dialogue Agent Output ===
# User: 575
#
# Critique:
# The current list leans heavily on action, adventure, and romantic
# elements, potentially overlooking the value of diverse emotional depth found
# in musicals, children's films, and animations. The absence of a
# musical and a children's movie might limit the breadth of
# emotional resonance and thematic exploration. To enhance its thematic richness,
# consider incorporating a film like "La La Land" (2016) (Musical
#
# DiversityReranker:
#                               title                              genres  \
# 0        Princess Bride, The (1987)  Action, Adventure, Comedy, Romance
# 1  James and the Giant Peach (1996)      Animation, Children's, Musical
# 2                 Casablanca (1942)                 Drama, Romance, War
# 3   Star Trek: First Contact (1996)           Action, Adventure, Sci-Fi
# 4           Some Like It Hot (1959)                       Comedy, Crime
#
#    predicted_rating
# 0          4.014057
# 1          4.084610
# 2          3.912789
# 3          3.920164
# 4          4.095374
#
# --- User History ---
#                                                                title                            genres  rating
#                                                                 Babe         Children's, Comedy, Drama       5
#                                                          Chasing Amy                    Drama, Romance       5
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb                       Sci-Fi, War       5
#                             Haunted World of Edward D. Wood Jr., The                       Documentary       5
#                                            Last of the Mohicans, The              Action, Romance, War       5
#                                                       Secrets & Lies                             Drama       5
#                                                             Spy Hard                            Comedy       5
#                                                              unknown                           unknown       5
#                                                          Dragonheart        Action, Adventure, Fantasy       4
#                                                         Men in Black Action, Adventure, Comedy, Sci-Fi       4
# --- Top-20 recommendations before re-ranking ---
# 1. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.31
# 2. Some Like It Hot (1959) (Comedy, Crime) → pred 4.24
# 3. Quartier Mozart (1992) (Comedy) → pred 4.22
# 4. American in Paris, An (1951) (Musical, Romance) → pred 4.20
# 5. I.Q. (1994) (Comedy, Romance) → pred 4.16
# 6. Father of the Bride Part II (1995) (Comedy) → pred 4.11
# 7. Santa Clause, The (1994) (Children's, Comedy) → pred 4.08
# 8. Transformers: The Movie, The (1986) (Action, Animation, Children's, Sci-Fi, Thriller, War) → pred 4.07
# 9. Bringing Up Baby (1938) (Comedy) → pred 4.06
# 10. Monty Python and the Holy Grail (1974) (Comedy) → pred 4.06
# 11. Jack and Sarah (1995) (Romance) → pred 4.03
# 12. M (1931) (Crime, Film-Noir, Thriller) → pred 4.00
# 13. Lay of the Land, The (1997) (Comedy, Drama) → pred 3.99
# 14. Spy Hard (1996) (Comedy) → pred 3.97
# 15. Delicatessen (1991) (Comedy, Sci-Fi) → pred 3.94
# 16. In & Out (1997) (Comedy) → pred 3.93
# 17. Kaspar Hauser (1993) (Drama) → pred 3.92
# 18. Client, The (1994) (Drama, Mystery, Thriller) → pred 3.92
# 19. Butcher Boy, The (1998) (Drama) → pred 3.92
# 20. In the Name of the Father (1993) (Drama) → pred 3.90
#
# === Dialogue Agent Output ===
# User: 198
#
# Critique:
# The current recommendation strategy appears to favor action-oriented films, with
# a notable absence of musicals and children's films. This restricts
# the thematic richness and emotional depth, as diverse genres can
# evoke a wider range of emotions and explore various themes.
# The lack of genre variety, particularly the omission of musicals
# and children's films, could limit the appeal to a broader
# audience. To enhance the recommendation strategy, incorporating
#
# DiversityReranker:
#                                  title  \
# 0  Transformers: The Movie, The (1986)
# 1                   Client, The (1994)
# 2                             M (1931)
# 3                          I.Q. (1994)
# 4         American in Paris, An (1951)
#
#                                               genres  predicted_rating
# 0  Action, Animation, Children's, Sci-Fi, Thrille...          4.072067
# 1                           Drama, Mystery, Thriller          3.920957
# 2                         Crime, Film-Noir, Thriller          3.997353
# 3                                    Comedy, Romance          4.162356
# 4                                   Musical, Romance          4.198583
#
# --- User History ---
#                              title                  genres  rating
#                                187                   Drama       5
#              American in Paris, An        Musical, Romance       5
#                     Apocalypse Now              Drama, War       5
#                       Delicatessen          Comedy, Sci-Fi       5
#                 Gone with the Wind     Drama, Romance, War       5
#                            Hoodlum Crime, Drama, Film-Noir       5
#          House of the Spirits, The          Drama, Romance       5
#                               I.Q.         Comedy, Romance       5
# Indiana Jones and the Last Crusade       Action, Adventure       5
#               Meet Me in St. Louis                 Musical       5
# --- Top-20 recommendations before re-ranking ---
# 1. Quartier Mozart (1992) (Comedy) → pred 4.45
# 2. Butcher Boy, The (1998) (Drama) → pred 4.36
# 3. Good Man in Africa, A (1994) (Action, Adventure) → pred 4.33
# 4. American in Paris, An (1951) (Musical, Romance) → pred 4.26
# 5. Dances with Wolves (1990) (Adventure, Drama, Western) → pred 4.25
# 6. Tin Cup (1996) (Comedy, Romance) → pred 4.24
# 7. Henry V (1989) (Drama, War) → pred 4.22
# 8. I.Q. (1994) (Comedy, Romance) → pred 4.22
# 9. Cook the Thief His Wife & Her Lover, The (1989) (Drama) → pred 4.21
# 10. In & Out (1997) (Comedy) → pred 4.21
# 11. Transformers: The Movie, The (1986) (Action, Animation, Children's, Sci-Fi, Thriller, War) → pred 4.20
# 12. Dave (1993) (Comedy, Romance) → pred 4.17
# 13. Free Willy (1993) (Adventure, Children's, Drama) → pred 4.17
# 14. Sleepless in Seattle (1993) (Comedy, Romance) → pred 4.16
# 15. M (1931) (Crime, Film-Noir, Thriller) → pred 4.16
# 16. Army of Darkness (1993) (Action, Adventure, Comedy, Horror, Sci-Fi) → pred 4.16
# 17. Alien: Resurrection (1997) (Action, Horror, Sci-Fi) → pred 4.15
# 18. Lay of the Land, The (1997) (Comedy, Drama) → pred 4.12
# 19. Princess Bride, The (1987) (Action, Adventure, Comedy, Romance) → pred 4.12
# 20. Kaspar Hauser (1993) (Drama) → pred 4.11
#
# === Dialogue Agent Output ===
# User: 168
#
# Critique:
# The recommendations primarily focus on action-oriented and thrilling genres, with
# a notable absence of musicals, children's films, and animation. This
# narrow thematic scope may not cater to diverse audience preferences.
# Introducing a classic musical like "Singin' in the Rain" (1952)
# could significantly enhance the thematic richness and emotional depth of
# the list. Improvement suggestion: Incorporate "Singin' in the
#
# DiversityReranker:
#                                  title  \
# 0  Transformers: The Movie, The (1986)
# 1           Princess Bride, The (1987)
# 2                             M (1931)
# 3            Dances with Wolves (1990)
# 4           Alien: Resurrection (1997)
#
#                                               genres  predicted_rating
# 0  Action, Animation, Children's, Sci-Fi, Thrille...          4.198920
# 1                 Action, Adventure, Comedy, Romance          4.120688
# 2                         Crime, Film-Noir, Thriller          4.161266
# 3                          Adventure, Drama, Western          4.250651
# 4                             Action, Horror, Sci-Fi          4.146999
#
# --- User History ---
#                      title                            genres  rating
#                  Apt Pupil                   Drama, Thriller       5
#                Client, The          Drama, Mystery, Thriller       4
#         Dances with Wolves         Adventure, Drama, Western       4
#  In the Name of the Father                             Drama       4
#               Jackie Brown                      Crime, Drama       4
#               Men in Black Action, Adventure, Comedy, Sci-Fi       4
#          Professional, The   Crime, Drama, Romance, Thriller       4
#          Santa Clause, The                Children's, Comedy       4
#          Starship Troopers    Action, Adventure, Sci-Fi, War       4
# Terminator 2: Judgment Day          Action, Sci-Fi, Thriller       4
# --- Top-20 recommendations before re-ranking ---
# 1. Quartier Mozart (1992) (Comedy) → pred 4.72
# 2. Some Like It Hot (1959) (Comedy, Crime) → pred 4.40
# 3. Starship Troopers (1997) (Action, Adventure, Sci-Fi, War) → pred 4.30
# 4. Until the End of the World (Bis ans Ende der Welt) (1991) (Drama, Sci-Fi) → pred 4.28
# 5. Empire Strikes Back, The (1980) (Action, Adventure, Drama, Romance, Sci-Fi, War) → pred 4.25
# 6. Around the World in 80 Days (1956) (Adventure, Comedy) → pred 4.24
# 7. Roman Holiday (1953) (Comedy, Romance) → pred 4.24
# 8. Snow White and the Seven Dwarfs (1937) (Animation, Children's, Musical) → pred 4.23
# 9. Tin Cup (1996) (Comedy, Romance) → pred 4.21
# 10. Midnight in the Garden of Good and Evil (1997) (Comedy, Crime, Drama, Mystery) → pred 4.20
# 11. Citizen Kane (1941) (Drama) → pred 4.20
# 12. American in Paris, An (1951) (Musical, Romance) → pred 4.16
# 13. Spy Hard (1996) (Comedy) → pred 4.15
# 14. In & Out (1997) (Comedy) → pred 4.15
# 15. Client, The (1994) (Drama, Mystery, Thriller) → pred 4.14
# 16. M (1931) (Crime, Film-Noir, Thriller) → pred 4.14
# 17. Amadeus (1984) (Drama, Mystery) → pred 4.14
# 18. Father of the Bride Part II (1995) (Comedy) → pred 4.14
# 19. Butcher Boy, The (1998) (Drama) → pred 4.14
# 20. Santa Clause, The (1994) (Children's, Comedy) → pred 4.13
#
# === Dialogue Agent Output ===
# User: 162
#
# Critique:
# While the recommendations offer a diverse range of genres, the
# list leans heavily on the action and adventure genres, with
# Empire Strikes Back and Midnight in the Garden of Good
# and Evil. The emotional depth is somewhat limited, as these
# films prioritize thrilling plots over character development. The absence of
# musicals and more recent animated films suggests a potential gap
# in thematic richness and contemporary appeal. Including a modern animated
# mus
#
# DiversityReranker:
#                                             title  \
# 0                 Empire Strikes Back, The (1980)
# 1                                        M (1931)
# 2          Snow White and the Seven Dwarfs (1937)
# 3  Midnight in the Garden of Good and Evil (1997)
# 4                        Santa Clause, The (1994)
#
#                                            genres  predicted_rating
# 0  Action, Adventure, Drama, Romance, Sci-Fi, War          4.253781
# 1                      Crime, Film-Noir, Thriller          4.144231
# 2                  Animation, Children's, Musical          4.225530
# 3                   Comedy, Crime, Drama, Mystery          4.202675
# 4                              Children's, Comedy          4.131974
